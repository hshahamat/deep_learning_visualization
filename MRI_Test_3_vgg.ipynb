# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
data_path = "drive/My Drive/ABRO/"
# !ls "drive/My Drive/ABRO/ADNI/"

from IPython.display import clear_output
# !cd "drive/My Drive/ABRO/Atlas/" && unrar e MASKS_MNI2mm.rar
# Out:
# Mounted at /content/drive
# AD  CN

# %%
import nibabel as nib
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
import glob

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

######################
###Model Parameters###

alpha = 0.025
betha = 1 - alpha

width = 80
height = 80
depth = 60
nLabel = 2
#####################

fRange1 = slice(6,86)
fRange2 = slice(16,96)
fRange3 = slice(16,76)

# %%
def norm(A):
       return (A-np.amin(A))/(np.amax(A)-np.amin(A))

_data = []
_labels = []
G=glob.glob(data_path+'ADNI/AD/*.gz')
for _g in G:
    n1_img = nib.load(_g)
    print(_g)
    tmp=np.array(n1_img.get_fdata())
    tmp=tmp[fRange1,fRange2,fRange3]
    _data.append(norm(tmp))
    _labels.append(1)


G=glob.glob(data_path+'ADNI/CN/*.gz')
for _g in G:
    n1_img = nib.load(_g)
    print(_g)
    tmp=np.array(n1_img.get_fdata())
    tmp=tmp[fRange1,fRange2,fRange3]
    _data.append(norm(tmp))
    _labels.append(0)

#################################
###########Loading Masks#########
G =sorted(glob.glob(data_path+'Atlas/*.nii'))
Bmasks = np.zeros((width, height, depth, len(G)), dtype=bool)
Template = np.zeros((width, height, depth), dtype=bool)
idx = 0
for g in G:
    n1_img = nib.load(g)
    tmp = np.array(n1_img.get_fdata())
    tmp = tmp[fRange1, fRange2, fRange3] > 0
    Bmasks[..., idx] = tmp
    idx += 1
    Template = np.logical_or(Template, tmp)    
Template = np.logical_not(Template)
#################################

clear_output()
_data = np.array(_data, dtype=np.float32)#[...,np.newaxis]
_labels = np.array(_labels)

print('_data.shape=>', _data.shape)
print('_labels.shape=>', _labels.shape)
# Out:
# _data.shape=> (145, 80, 80, 60)
# _labels.shape=> (145,)

# %%
from sklearn.model_selection import train_test_split 
# from tensorflow.keras.utils import to_categorical

# oh_labels = to_categorical(_labels)

x_train, x_test, y_train, y_test  = train_test_split(_data, _labels,
                              train_size=.8,random_state=123,shuffle=True)

del _data
del _labels
print('x_train.shape=>', x_train.shape)
print('y_train.shape=>', y_train.shape)
print('x_test.shape=>', x_test.shape)
print('y_test.shape=>', y_test.shape)
# Out:
# x_train.shape=> (116, 80, 80, 60)
# y_train.shape=> (116,)
# x_test.shape=> (29, 80, 80, 60)
# y_test.shape=> (29,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv3D,MaxPooling3D,Flatten
from tensorflow import keras

def get_model(width=80, height=80, depth=80):
    model = Sequential()
    model.add(keras.Input(shape=(width, height, depth, 1)))
    model.add(Conv3D(64, (3, 3,3),
           activation='relu',
           padding='same',
           name='block1_conv1',
           input_shape=(80,80,80,1)))
    model.add(Conv3D(64, (3, 3,3),
           activation='relu',
           padding='same',
           name='block1_conv2'))
    model.add(MaxPooling3D(
            pool_size=(2, 2,2),
            strides=(2, 2,2),
            name='block1_pool',
            padding='same'
    ))

    model.add(Conv3D(128, (3, 3,3),
                      activation='relu',
                      padding='same',
                      name='block2_conv1'))
    model.add(Conv3D(128, (3, 3,3),
           activation='relu',
           padding='same',
           name='block2_conv2'))
    model.add(MaxPooling3D((2,2, 2), strides=(2,2, 2),#padding='same',
                           name='block2_pool'
                           ))

    model.add(Conv3D(256, (3, 3,3),
                      activation='relu',
                      padding='same',
                      name='block3_conv1'))
    model.add(Conv3D(256, (3,3, 3),
                      activation='relu',
                      padding='same',
                      name='block3_conv2'))
    model.add(Conv3D(256, (3,3, 3),
                      activation='relu',
                      padding='same',
                      name='block3_conv3'))
    model.add(MaxPooling3D((2,2, 2), strides=(2,2, 2),padding='same', name='block3_pool'))

    model.add(Flatten(name='flatten'))
    model.add(Dense(512, activation='relu',name='fc1'))

    model.add(Dense(128, activation='relu',name='fc2'))

    model.add(Dense(1, activation='sigmoid', name='predictions'))
    # print(model.summary())
    return model

# %%
# Load best weights.
model = get_model(width=width, height=height, depth=depth)
model.load_weights(data_path+"chkp/3d_MRI_classification_vgg.h5")
prediction=[]
_bs = 16
for i in range(0,x_test.shape[0],_bs):
    XTD = x_test[i:min(i+_bs,x_test.shape[0]),...]
    XTD = XTD[...,np.newaxis]
    _pred = model.predict(XTD)[:,0]
    prediction.extend(_pred.tolist())
prediction = np.array(prediction)
# for _p in range(len(prediction)):
#     scores = np.array([1 - prediction[_p], prediction[_p]])
#     class_names = ["normal", "abnormal"]
#     print('Real label is =>',class_names[y_test[_p]])
#     score = scores.max()
#     name = class_names[scores.argmax()]
#     print(
#         "This model is %.2f percent confident that MRI scan is %s"
#         % ((score), name)
#     )
#     print('<##>'*10)


y_pred = np.where(prediction<0.5,0,1)
y_true = y_test

from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
Accuracy = (tp + tn) / (tp + fp + fn + tn)
ACC = Accuracy.sum()
print('Confusion matrix(test):\n{}'.format(confusion_matrix(y_true, y_pred)))
print("Accuracy", ACC)
Precision = tp/(tp+fp)
print("Precision", Precision)
Recall = tp/(tp+fn)
print("Recall",Recall)
# Out:
# Confusion matrix(test):
# [[12  0]
#  [ 4 13]]
# Accuracy 0.8620689655172413
# Precision 1.0
# Recall 0.7647058823529411

# %%
def rand_gen(siz):
    r = np.random.rand(siz)
    t = np.zeros(r.shape)
    t[np.logical_and(r >= 0.1, r < 0.4)] = 1
    t[np.logical_and(r >= 0.4, r < 0.7)] = 2
    t[np.logical_and(r >= 0.7, r < 1.0)] = 3
    if siz>5:
        tmpr = np.random.rand()
        if tmpr>0.5:
            t = np.ones(r.shape)            
    return t


def mutation(DNAp):
    DNAc = np.copy(DNAp)
    point = np.random.randint(0,len(DNAc))
    DNAc[point] = rand_gen(1)
    return DNAc


def crossover(DNAp1, DNAp2):
    point = np.random.randint(1, len(DNAp1) - 1)
    DNAc1 = np.append(DNAp1[:point], DNAp2[point:])
    DNAc2 = np.append(DNAp2[:point], DNAp1[point:])
    return DNAc1, DNAc2


def selectp(fitness, N):
    f_sum = np.sum(fitness)
    idxs = []
    for i in range(N):
        pick = np.random.uniform(0, f_sum-0.001)
        current = 0
        for per in range(len(fitness)):
            current += fitness[per]
            if current > pick:
                idxs.append(per)
                break
    return np.array(idxs)


def Chromosome2Mask(Bmasks, DNA, Template):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
    Mask = Template.copy()
    for i in range(len(DNA)):
        if DNA[i] == 1:
            Mask = np.logical_or(Mask, Bmasks[..., i])
        if DNA[i] == 2:
            M = Bmasks[..., i]
            TM = cv2.dilate(M.astype(np.uint8), kernel, iterations=1)
            Mask = np.logical_or(Mask, TM.astype(np.bool))
        if DNA[i] == 3:
            M = Bmasks[..., i]
            TM = cv2.erode(M.astype(np.uint8), kernel, iterations=1)
            Mask = np.logical_or(Mask, TM.astype(np.bool))
    return Mask



def fit_func(Xdata, Ydata, Bmasks, DNA, Template):
    _mask = Chromosome2Mask(Bmasks, DNA, Template)
    # XTD = np.zeros_like(Xdata,dtype=np.float32)
    prediction=[]
    _bs = 16
    for i in range(0,Xdata.shape[0],_bs):
        XTD = np.multiply(Xdata[i:min(i+_bs,Xdata.shape[0]),...], _mask)
        # XTD = XTD[np.newaxis,...]
        XTD = XTD[...,np.newaxis]
        _pred = model.predict(XTD)[:,0]
        prediction.extend(_pred.tolist())
    prediction = np.array(prediction)
    
    Ypred = np.where(prediction<0.5,0,1)
    fitval1 = (np.sum(Ypred==Ydata))/len(Ydata)
    # print(Ypred,Ydata)
    tmp = np.sum(DNA > 0)
    if tmp == 0:
        tmp = 10000
    fitval2 = 1 / (tmp)
    # print(fitval1 ,fitval2)
    fitval = ((fitval1 * alpha) + (fitval2 * betha))
    return fitval1, np.sum(DNA > 0), fitval

# Best_DNA=np.ones(96)
# Mask=Chromosome2Mask(Bmasks,Best_DNA,Template)

# %%
###########Applaying GA #########
#################################
MAX_ITER = 1000
npop = 20
nvar = 96
pcrossover = 0.4
pmutation = 0.6

npfc = int(pcrossover * npop)
npfm = int(pmutation * npop)
POP_DNA = np.zeros((npop, nvar))
POP_Fitval = np.zeros(npop)
Best_DNA = []
Best_Fitval = 0
for i in range(0, npop):
    POP_DNA[i, :] = rand_gen(nvar)
    _,_,POP_Fitval[i] = fit_func(x_train, y_train, Bmasks, POP_DNA[i, :], Template)

FPI = np.zeros(MAX_ITER)
RPI = np.zeros(MAX_ITER)
API = np.zeros(MAX_ITER)
TAPI = np.zeros(MAX_ITER)
all_best_dna = []
for iter in range(0, MAX_ITER):
    POP_C_DNA = np.zeros((npfc, nvar))
    POP_C_Fitval = np.zeros(npfc)
    POP_M_DNA = np.zeros((npfm, nvar))
    POP_M_Fitval = np.zeros(npfm)
    tmp = selectp(POP_Fitval, npfc)
    IDXc = tmp.astype(np.int)
    for i in range(0, npfc, 2):
        c1, c2 = crossover(POP_DNA[IDXc[i], :], POP_DNA[IDXc[i + 1], :])
        POP_C_DNA[i, :] = c1
        _,_,POP_C_Fitval[i] = fit_func(x_train, y_train, Bmasks, c1, Template)
        POP_C_DNA[i + 1, :] = c2
        _,_,POP_C_Fitval[i + 1] = fit_func(x_train, y_train, Bmasks, c2, Template)

    tmp = selectp(POP_Fitval, npfm)
    IDXm = tmp.astype(np.int)
    for i in range(0, npfm):
        c = mutation(POP_DNA[IDXm[i], :])
        POP_M_DNA[i, :] = c
        _,_,POP_M_Fitval[i] = fit_func(x_train, y_train, Bmasks, c, Template)

    NPOP_DNA = np.vstack((POP_DNA, POP_C_DNA, POP_M_DNA))
    NPOP_Fitval = np.hstack((POP_Fitval, POP_C_Fitval, POP_M_Fitval))
    Sidx = np.argsort(-NPOP_Fitval)
    NPOP_DNA = NPOP_DNA[Sidx, :]
    NPOP_Fitval = NPOP_Fitval[Sidx]

    if NPOP_Fitval[0] > Best_Fitval:
        Best_Fitval = NPOP_Fitval[0]
        Best_DNA = NPOP_DNA[0, :]

    POP_DNA = NPOP_DNA[:npop, :]
    POP_Fitval = NPOP_Fitval[:npop]

    A, R, F = fit_func(x_train, y_train, Bmasks, Best_DNA, Template)

    FPI[iter] = F
    RPI[iter] = R
    API[iter] = A
    all_best_dna.append(Best_DNA)
    TA,_,_ = fit_func(x_test, y_test, Bmasks, Best_DNA, Template)
    TAPI[iter] = TA
    print('iter=>',iter,'train_accuracy=>', A, 'test_accuracy=>', TA, 'ROI_num=>', R)


    all_best_dna_tmp = np.array(all_best_dna)
    np.save(data_path+'GA_res/vgg2ALLBestDNA'+'_'+str(alpha), all_best_dna_tmp)
    np.savetxt(data_path+"GA_res/vgg2TestGA"+"_"+str(alpha)+".csv", np.vstack((FPI, RPI, API, TAPI)), delimiter=",", fmt='%10.3f')
    np.save(data_path+'GA_res/vgg0BestDNA'+'_'+str(alpha), Best_DNA)
# Out:
# iter=> 0 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 85
# iter=> 1 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 84
# iter=> 2 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 81
# iter=> 3 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 81
# iter=> 4 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 81
# iter=> 5 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 81
# iter=> 6 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 81
# iter=> 7 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 81
# iter=> 8 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.8620689655172413 ROI_num=> 79
# iter=> 9 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.8620689655172413 ROI_num=> 79
# iter=> 10 train_accuracy=> 1.0 test_accuracy=> 0.7931034482758621 ROI_num=> 80
# iter=> 11 train_accuracy=> 1.0 test_accuracy=> 0.7931034482758621 ROI_num=> 80
# iter=> 12 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 78
# iter=> 13 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 78
# iter=> 14 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 78
# iter=> 15 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 78
# iter=> 16 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 78
# iter=> 17 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 78
# iter=> 18 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 76
# iter=> 19 train_accuracy=> 1.0 test_accuracy=> 0.9310344827586207 ROI_num=> 77
# iter=> 20 train_accuracy=> 1.0 test_accuracy=> 0.9310344827586207 ROI_num=> 77
# iter=> 21 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 75
# iter=> 22 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 73
# iter=> 23 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 73
# iter=> 24 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 73
# iter=> 25 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 73
# iter=> 26 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 27 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 28 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 29 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 30 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 31 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 32 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 72
# iter=> 33 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 71
# iter=> 34 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 71
# iter=> 35 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 71
# iter=> 36 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 70
# iter=> 37 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 70
# iter=> 38 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 39 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 40 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 41 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 42 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 43 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 44 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 45 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 46 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 47 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 69
# iter=> 48 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 68
# iter=> 49 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 68
# iter=> 50 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 68
# iter=> 51 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 68
# iter=> 52 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 67
# iter=> 53 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 67
# iter=> 54 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 67
# iter=> 55 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 67
# iter=> 56 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 67
# iter=> 57 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 66
# iter=> 58 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 66
# iter=> 59 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 66
# iter=> 60 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 65
# iter=> 61 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 64
# iter=> 62 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 64
# iter=> 63 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 63
# iter=> 64 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 63
# iter=> 65 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 63
# iter=> 66 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 62
# iter=> 67 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 62
# iter=> 68 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 62
# iter=> 69 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 61
# iter=> 70 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 61
# iter=> 71 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 61
# iter=> 72 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 60
# iter=> 73 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 60
# iter=> 74 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 60
# iter=> 75 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 60
# iter=> 76 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 60
# iter=> 77 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 59
# iter=> 78 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 59
# iter=> 79 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 59
# iter=> 80 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 59
# iter=> 81 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 58
# iter=> 82 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 58
# iter=> 83 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 57
# iter=> 84 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 57
# iter=> 85 train_accuracy=> 1.0 test_accuracy=> 0.8275862068965517 ROI_num=> 56
# iter=> 86 train_accuracy=> 1.0 test_accuracy=> 0.8275862068965517 ROI_num=> 56
# iter=> 87 train_accuracy=> 1.0 test_accuracy=> 0.8275862068965517 ROI_num=> 56
# iter=> 88 train_accuracy=> 1.0 test_accuracy=> 0.8275862068965517 ROI_num=> 56
# iter=> 89 train_accuracy=> 1.0 test_accuracy=> 0.8275862068965517 ROI_num=> 56
# iter=> 90 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 55
# iter=> 91 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 55
# iter=> 92 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 55
# iter=> 93 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 54
# iter=> 94 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 54
# iter=> 95 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 54
# iter=> 96 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 53
# iter=> 97 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 53
# iter=> 98 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 53
# iter=> 99 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 52
# iter=> 100 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 52
# iter=> 101 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 51
# iter=> 102 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 51
# iter=> 103 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 51
# iter=> 104 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 51
# iter=> 105 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 51
# iter=> 106 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 107 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 108 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 109 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 110 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 111 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 112 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 113 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 114 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 50
# iter=> 115 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 49
# iter=> 116 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 49
# iter=> 117 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 49
# iter=> 118 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.8620689655172413 ROI_num=> 47
# iter=> 119 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.8620689655172413 ROI_num=> 47
# iter=> 120 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.8620689655172413 ROI_num=> 47
# iter=> 121 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 47
# iter=> 122 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 46
# iter=> 123 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 46
# iter=> 124 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 46
# iter=> 125 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 46
# iter=> 126 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 45
# iter=> 127 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 45
# iter=> 128 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 45
# iter=> 129 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 44
# iter=> 130 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 44
# iter=> 131 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 43
# iter=> 132 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 43
# iter=> 133 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 134 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 135 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 136 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 137 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 138 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 139 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 140 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 42
# iter=> 141 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 142 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 143 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 144 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 145 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 146 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 147 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 148 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 149 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 150 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 151 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 41
# iter=> 152 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 40
# iter=> 153 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 40
# iter=> 154 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 40
# iter=> 155 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 40
# iter=> 156 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 40
# iter=> 157 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 40
# iter=> 158 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 159 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 160 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 161 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 162 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 163 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 164 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 165 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 166 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 167 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 168 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 39
# iter=> 169 train_accuracy=> 0.9741379310344828 test_accuracy=> 0.896551724137931 ROI_num=> 38
# iter=> 170 train_accuracy=> 0.9741379310344828 test_accuracy=> 0.896551724137931 ROI_num=> 38
# iter=> 171 train_accuracy=> 0.9741379310344828 test_accuracy=> 0.896551724137931 ROI_num=> 38
# iter=> 172 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 38
# iter=> 173 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 38
# iter=> 174 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 38
# iter=> 175 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 38
# iter=> 176 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 37
# iter=> 177 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 37
# iter=> 178 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 37
# iter=> 179 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 37
# iter=> 180 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 37
# iter=> 181 train_accuracy=> 1.0 test_accuracy=> 0.8620689655172413 ROI_num=> 37
# iter=> 182 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 183 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 184 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 185 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 186 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 187 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 188 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 189 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 36
# iter=> 190 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 35
# iter=> 191 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 35
# iter=> 192 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 35
# iter=> 193 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.8620689655172413 ROI_num=> 34
# iter=> 194 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.8620689655172413 ROI_num=> 34
# iter=> 195 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.8620689655172413 ROI_num=> 34
# iter=> 196 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 197 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 198 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 199 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 200 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 201 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 202 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 203 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 204 train_accuracy=> 1.0 test_accuracy=> 0.896551724137931 ROI_num=> 34
# iter=> 205 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 33
# iter=> 206 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 33
# iter=> 207 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 33
# iter=> 208 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 33
# iter=> 209 train_accuracy=> 0.9913793103448276 test_accuracy=> 0.896551724137931 ROI_num=> 33
# iter=> 210 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 32
# iter=> 211 train_accuracy=> 0.9741379310344828 test_accuracy=> 0.8620689655172413 ROI_num=> 32
# iter=> 212 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.896551724137931 ROI_num=> 32
# iter=> 213 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.896551724137931 ROI_num=> 32
# iter=> 214 train_accuracy=> 0.9827586206896551 test_accuracy=> 0.896551724137931 ROI_num=> 32
# iter=> 215 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.8275862068965517 ROI_num=> 31
# iter=> 216 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 217 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 218 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 219 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 220 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 221 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 222 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 30
# iter=> 223 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 29
# iter=> 224 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 29
# iter=> 225 train_accuracy=> 0.9568965517241379 test_accuracy=> 0.896551724137931 ROI_num=> 29

# %%
    # np.savetxt(data_path+"2TestGA"+"_"+str(alpha)+".csv", np.vstack((FPI, RPI, API, TAPI)), delimiter=",", fmt='%10.3f')
    # np.save(data_path+'2BestDNA'+'_'+str(alpha), Best_DNA)
import pandas as pd
df=pd.read_csv(data_path+"GA_res/vgg2TestGA"+"_"+str(alpha)+".csv", sep=',',header=None)
_info = df.values[:,:500]
# Best_DNA = np.load(data_path+'0BestDNA'+'_'+str(alpha)+'.npy')

tit = ["GABM_Fitness", "Number_of_selected_brain_regions","Train_Accuracy","Test_Accuracy"]
# plt.subplots_adjust(top=3.8)
_fs = (15, 3)

i=0
plt.figure(figsize=_fs)
plt.plot(_info[i,:], 'r-.')
plt.xlabel("Iteration")
plt.ylabel("Fit_val")
plt.title(tit[i])
plt.show()
print(' ')

i=1
plt.figure(figsize=_fs)
plt.plot(_info[i,:], 'g-.')
plt.xlabel("Iteration")
plt.ylabel("# ROI")
plt.ylim(0,96)
plt.title(tit[i])
plt.show()
print(' ')

i=2
plt.figure(figsize=_fs)
plt.plot(_info[i,:], 'b-.')
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.ylim(0.0,1.01)
plt.title(tit[i])
plt.show()
print(' ')

i=3
plt.figure(figsize=_fs)
plt.plot(_info[i,:], 'k-.')
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.ylim(0.0,1.01)
plt.title(tit[i])
plt.show()

all_best_dna=np.load(data_path+'GA_res/vgg2ALLBestDNA'+'_'+str(alpha)+'.npy')
Best_DNA = all_best_dna[430,:]
np.sum(Best_DNA>0)
# Out:
# 22

# %%
def plot_slices(num_rows, num_columns, width, height, data,cmap="gray"):
    """Plot a montage of 20 MRI slices"""
    data = np.rot90(np.array(data))
    if len(data.shape)==3:
        data = np.transpose(data)
        data = np.reshape(data, (num_rows, num_columns, width, height))
    else:
        data = np.transpose(data,[3,1,0,2])
        data = np.reshape(data, (num_rows, num_columns, width, height, 3))

    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            t_data = data[i][j]     
            axarr[i, j].imshow(t_data, cmap=cmap)
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()




Mask = Chromosome2Mask(Bmasks, Best_DNA, np.zeros((80, 80, 80), dtype=bool))
plot_slices(4, 10, 80, 80, Mask[:, :, 10:50])

t_img = x_test[0]
t_img = np.multiply(t_img, Mask)
plot_slices(4, 10, 80, 80, t_img[:, :, 10:50])

t_img = x_test[0]
t_res = np.zeros((80,80,3,80),dtype=np.float32)
for i in range(Mask.shape[2]):
    _msk = Mask[:, :, i]*1.0
    _msk = _msk.astype(np.float32)
    _img = t_img[:, :, i]
    _img = (_img-_img.min())/(_img.max()-_img.min())
    c_img = cv2.merge((_img,_img,_img))
    c_msk = cv2.merge((_msk,_msk*0.1,np.zeros_like(_msk)))
    t_res[...,i] = cv2.addWeighted(c_img,0.4,c_msk,0.2,0)

plot_slices(4, 10, 80, 80, t_res[:, :, :, 10:50],cmap=None)
